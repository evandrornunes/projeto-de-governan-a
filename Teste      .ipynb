# %% [markdown]
# <a href="https://colab.research.google.com/github/evandrornunes/projeto-de-governan-a/blob/main/Teste%20%20%20%20%20%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ✅ Math: biblioteca / Modulos

# %%
import math

math.sqrt(25)
math.log2(1024)
math.cos(45)
# Out:
# 0.5253219888177297

# %%
import math as m
m.sqrt(25)
m.log2(1024)
m.cos(45)
# Out:
# 0.5253219888177297

# %%
from math import sqrt, log2, cos
sqrt(25)
log2(1024)
cos(45)
# Out:
# 0.5253219888177297

# %% [markdown]
# ✅ Metplotlib - Graficos

# %%
import matplotlib.pyplot as plt

# Dados
Eixo_y = [2, 3, 4, 5, 6]
Eixo_x = [2, 4, 1, 8, 5]
# Criar um gráfico de linha
plt.plot(Eixo_y, Eixo_x)
# Adicionar rótulos ao eixo.
plt.xlabel('Eixo y')
plt.ylabel('Eixo x')
# Adicionar um título ao gráfico.
plt.title('Gráfico de Linha')
# Exibir o gráfico.
plt.show()
